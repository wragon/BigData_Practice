# %% [markdown]
# ## 1. 빅데이터를 통한 가치 창출 방안을 위한 분석 방법의 적용이 가장 맞지 않는 것은?  ( 4  )
# ### - 괄호안에 숫자 넣기
#
# 1. 소비자 요구 발견 - SNS 빈도 분석
# 2. 소비자 별 제품 추천 - 성별 구매 품목 교차 분석
# 3. 알고리즘을 통한 가격 결정 - 유사 판매 데이터 회귀분석
# 4. 새로운 비즈니스 모델, 상품, 서비스 도출 - 구매 가격 분산 분석

# %% [markdown]
# ## 2. Data life cycle 단계와 사용될 수 있는 도구와 짝이 맞지 않는 것을 모두 고르시오 (    4      )
# ### - 복수 답변, 오답이 포함되면 감점, 2개 썼는데 하나맞고 하나 틀리면 0점
#
#
# 1. Data 소스 : web site, csv
# 2. Data 획득 : urllib
# 3. Data 정제 : dropna
# 4. Data 통합 : groupby
# 5. Data 분석 : counter
# 6. Data 탐색 : corr
# 7. 시각화 : wordcloud

# %% [markdown]
# # 실기 문제
# - 08.zip 안에 주어진 file을 이용하여 (이름이 같아도 내용이 다를 수 있음)
# - 특별한 지시가 없으면 답만 맞으면 됨 (답란을 만들어서 작성)
# - 실행 결과를 그대로 제출하되, running이 가능하도록 필요한 모든 코드나 라이브러리를 갖춰야 함
#
# ## 3.1  studentlist.csv와 footsize.csv를 이름을 key로 하여 merge하고

# %%
import pandas as pd
df= pd.read_csv("studentlist.csv", encoding="cp949")
dff= pd.read_csv("footsize.csv", encoding="cp949")
merge_df= pd.merge(df, dff, left_on='name', right_on='realname')
merge_df
# Out:
#    name sex  age  grade absence bloodtype  height  weight  dept realname  \
# 0   김길동  남자   23      3       유         O   165.3    68.2     2      김길동
# 1   이미린  여자   22      2       무        AB   170.1    53.0     3      이미린
# 2   김철수  남자   23      3       무        AB   196.3    85.7     2      김철수
# 3   손세수  여자   20      1       유         A   168.0    49.5     1      손세수
# 4   박미희  여자   21      2       무         O   162.0    52.0     3      박미희
# 5   강수친  여자   22      1       무         O   155.2    45.3     2      강수친
# 6   이희수  여자   23      1       무         A   176.9    55.0     1      이희수
# 7   이철린  남자   23      3       무         B   178.5    64.2     1      이철린
# 8   방희철  남자   22      2       무         B   176.1    61.3     3      방희철
# 9   박수호  남자   24      4       유         O   167.1    62.0     3      박수호
# 10  임동민  남자   22      2       무        AB   180.0    75.8     3      임동민
# 11  김민수  남자   21      1       무         A   162.2    55.3     1      김민수
# ...

# %%
df1 = merge_df[merge_df["grade"]==1]
df2 = merge_df[merge_df["grade"]==2]
df3 = merge_df[merge_df["grade"]==3]
temp = df1.append(df2, ignore_index=True)
df4 = temp.append(df3, ignore_index=True)
df4
# Out:
#    name sex  age  grade absence bloodtype  height  weight  dept realname  \
# 0   손세수  여자   20      1       유         A   168.0    49.5     1      손세수
# 1   강수친  여자   22      1       무         O   155.2    45.3     2      강수친
# 2   이희수  여자   23      1       무         A   176.9    55.0     1      이희수
# 3   김민수  남자   21      1       무         A   162.2    55.3     1      김민수
# 4   여수근  남자   21      1       무         A   169.2    62.2     2      여수근
# 5   이미린  여자   22      2       무        AB   170.1    53.0     3      이미린
# 6   박미희  여자   21      2       무         O   162.0    52.0     3      박미희
# 7   방희철  남자   22      2       무         B   176.1    61.3     3      방희철
# 8   임동민  남자   22      2       무        AB   180.0    75.8     3      임동민
# 9   김미진  여자   22      2       무         B   158.2    45.2     3      김미진
# 10  김길동  남자   23      3       유         O   165.3    68.2     2      김길동
# 11  김철수  남자   23      3       무        AB   196.3    85.7     2      김철수
# ...

# %% [markdown]
# ## 3.2 data에서 4학년을 제외한 나머지 사람들의 키와 발 사이즈를 plotting하시오(상관관계를 살펴볼 수 있게). 이때 성별로 color를 다르게 출력하시오

# %%
import matplotlib.pyplot as plt
colors = {'남자':'red', '여자':'blue'}

plt.scatter (  "height", "footsize", s=df4["grade"].apply(lambda x: x*10), 
                     c=df4['sex'].apply(lambda x: colors[x]), data=df4 )

plt.title("mid", fontsize=14)
plt.xlabel("height", fontsize=12)
plt.ylabel("footsize", fontsize=12)
plt.show()

# %%
df5 = merge_df[merge_df['grade']!=4]
colors = {'남자':'red', '여자':'blue'}

plt.scatter (  "height", "footsize", c=df5['sex'].apply(lambda x: colors[x]), data=df5 )

# %% [markdown]
# ## 4.1 naver.json 파일을 읽어 각 item의 description을 추출하고

# %%
import json
inputFileName = 'naver'
data = json.loads(open(inputFileName+'.json', 'r', encoding='utf-8').read())
file = data['items']
file
# Out:
# [{'title': 'DGB 변액연금 이젠 ETF 재테크도 인공지능으로',
#   'link': 'https://blog.naver.com/alsghdkdhd01?Redirect=Log&logNo=222319087357',
#   'description': 'AI (인공지능)가 관리 3. 국내, 해외 상관없이 가장 좋은 자산운용사의 ETF에 투자 이렇게 바뀌었습니다... 변액연금은 인공지능이 알아서 투자를 해주기 때문에 신경 쓰지 않아도 수익을 내줍니다 빅데이터... ',
#   'bloggername': '라이프디자인',
#   'bloggerlink': 'https://blog.naver.com/alsghdkdhd01',
#   'postdate': '20210422'},
#  {'title': 'ai 인공지능 관련주 ai로봇 로보스타, 로보티즈, 휴림로봇... ',
#   'link': 'https://blog.naver.com/japark6108?Redirect=Log&logNo=222300394371',
#   'description': '있도록 지능형 소프트웨어로 함께 구성이 되어있습니다. 5G통신 환경을 통해 3세대 솔루션 기술인 인공지능을 기반으로 한, 동사의 확장기술 그리고 구조 설계와 해석 기술을 바탕으로 배송 로봇을 개발하고... ',
#   'bloggername': '고인돌마을 이장',
#   'bloggerlink': 'https://blog.naver.com/japark6108',
#   'postdate': '20210406'},
#  {'title': '스마일라식라섹 인공지능 설계의 차이',
#   'link': 'https://blog.naver.com/sdk106?Redirect=Log&logNo=222302806260',
# ...

# %% [markdown]
# ## 4.2 description 중 명사를 추출하여 히스토그램으로 표시하시오

# %%
import re 
from konlpy.tag import Okt
from collections import Counter
description = ''

for item in file:
    if 'description' in item.keys():  
        description = description + re.sub(r'[^\w]', ' ', item['description']) +''   # 문자, 숫자만 남기기
        
nlp = Okt()
description_N = nlp.nouns(description)
count = Counter(description_N)

word_count = dict()

for tag, counts in count.most_common(50):
    if(len(str(tag))>1):
        word_count[tag] = counts

description_N
# Out:
# ['인공',
#  '지능',
#  '관리',
#  '국내',
#  '해외',
#  '가장',
#  '자산운용',
#  '사의',
#  '투자',
#  '변액',
#  '연금',
#  '인공',
#  '지능',
#  '투자',
#  '때문',
#  '신경',
#  '수익',
#  '빅데이터',
#  '지능',
#  '소프트웨어',
#  '구성',
#  '통신',
#  '환경',
#  '통해',
#  '세대',
#  '솔루션',
#  '기술',
#  '인공',
#  '지능',
#  '기반',
#  '동사',
#  '확장',
#  '기술',
#  '구조',
#  '설계',
#  '해석',
#  '기술',
#  '바탕',
#  '배송',
#  '로봇',
#  '개발',
#  '시력',
#  '교정',
#  '과정',
#  '발생',
#  '수',
#  '아주',
#  '오류',
#  '의사',
#  '판단',
#  '미스',
#  '이제',
#  '인공',
#  '지능',
#  '경력',
#  '의료',
#  '진과',
#  '비교',
#  '인공',
#  '지능',
#  '통한',
#  '설계',
#  '계산',
#  '명확',
#  '도',
#  '매우',
#  '알',
#  '체라',
#  '주가',
#  '전망',
#  '스노우',
#  '네이버',
#  '인공',
#  '지능',
#  '얼굴인식',
#  '관련',
#  '주',
#  '인공',
#  '지능',
#  '얼굴인식',
#  '스노우',
#  '단어',
#  '종종',
#  '등장',
#  '기사',
#  '크게',
#  '관심',
#  '얼굴인식',
#  '데이터',
#  '위',
#  '지능',
#  '융합',
#  '서비스',
#  '등',
#  '품목',
#  '만날',
#  '수',
#  '결합',
#  '클라우드',
#  '컴퓨팅',
#  '빅데이터',
#  '도',
#  '수',
#  '품목',
#  '부스',
#  '인공',
#  '지능',
#  '메타',
#  '버스',
# ...

# %%
import matplotlib
import matplotlib.pyplot as plt
from matplotlib import font_manager, rc
font_path = "c:/Windows/fonts/malgun.ttf"
font_name = font_manager.FontProperties(fname = font_path).get_name()
matplotlib.rc('font', family=font_name)

plt.figure(figsize=(12,5))
plt.xlabel('키워드')
plt.ylabel('빈도수')
plt.grid(True)

sorted_Keys = sorted(word_count, key=word_count.get, reverse=True)
sorted_Values = sorted(word_count.values(), reverse=True)

plt.bar(range(len(word_count)), sorted_Values, align='center')
plt.xticks(range(len(word_count)), list(sorted_Keys), rotation='75')

plt.show()

# %% [markdown]
# ## 5.1 아래 페이지를 가져와서
# https://ssu.ac.kr/%ea%b5%90%ec%9c%a1-%c2%b7-%ec%97%b0%ea%b5%ac/%eb%8c%80%ed%95%99%ec%86%8c%ea%b0%9c/it%eb%8c%80%ed%95%99/

# %%
from bs4 import BeautifulSoup 
import requests
url= "https://ssu.ac.kr/%ea%b5%90%ec%9c%a1-%c2%b7-%ec%97%b0%ea%b5%ac/%eb%8c%80%ed%95%99%ec%86%8c%ea%b0%9c/it%eb%8c%80%ed%95%99/"
response = requests.get(url)
if response.status_code == 200:
    html = response.text
    soup = BeautifulSoup(html, 'html.parser')
    print(soup)

else : 
    print(response.status_code)
# Out:
# <!DOCTYPE doctype html>
#
# <html lang="ko-KR">
# <head>
# <meta charset="utf-8"/>
# <meta content="width=device-width, initial-scale=1" name="viewport"/>
# <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
# <link href="https://gmpg.org/xfn/11" rel="profile"/>
# <title>IT대학 - 숭실대학교</title>
# <meta content="noindex,follow" name="robots">
# <link href="//developers.kakao.com" rel="dns-prefetch"/>
# <link href="//s.w.org" rel="dns-prefetch"/>
# <link href="https://ssu.ac.kr/feed/" rel="alternate" title="숭실대학교 » 피드" type="application/rss+xml"/>
# <link href="https://ssu.ac.kr/comments/feed/" rel="alternate" title="숭실대학교 » 댓글 피드" type="application/rss+xml"/>
# <script type="text/javascript">
# 			window._wpemojiSettings = {"baseUrl":"https:\/\/s.w.org\/images\/core\/emoji\/11.2.0\/72x72\/","ext":".png","svgUrl":"https:\/\/s.w.org\/images\/core\/emoji\/11.2.0\/svg\/","svgExt":".svg","source":{"concatemoji":"https:\/\/ssu.ac.kr\/wp-includes\/js\/wp-emoji-release.min.js?ver=5.1.1"}};
# ...

# %%
soup.find_all('a')
# Out:
# [<a class="d-block text-center" href="https://scatch.ssu.ac.kr/%ea%b3%b5%ec%a7%80%ec%82%ac%ed%95%ad/?f&amp;category&amp;slug=2021%ED%95%99%EB%85%84%EB%8F%84-%EA%B5%90%EC%A7%81%EA%B3%BC%EC%A0%95-%EC%9D%B4%EC%88%98-%EC%8B%A0%EC%B2%AD-%EC%95%88%EB%82%B4&amp;keyword">
#  <p class="tit text-truncate">2021학년도 교직과정 이수 신청 안내</p>
#  <p class="sub text-truncate">2021.05.01.~2021.12.10.</p>
#  </a>,
#  <a class="d-block text-center" href=" https://scatch.ssu.ac.kr/%ea%b3%b5%ec%a7%80%ec%82%ac%ed%95%ad/?f&amp;category=%EA%B5%90%EB%82%B4%ED%96%89%EC%82%AC&amp;slug=2021%ED%95%99%EB%85%84%EB%8F%84-%EC%A0%9C-11%ED%9A%8C-%EC%8B%A0%EC%9E%85%EC%83%9D-%ED%95%99%EB%B6%80%EB%AA%A8-%EC%B4%88%EC%B2%AD%ED%96%89%EC%82%AC-%EA%B0%9C%EC%B5%9C&amp;keyword">
#  <p class="tit text-truncate">제 11회 신입생 학부모 초청행사 개최</p>
#  <p class="sub text-truncate">2021.05.01.~2021.05.08.</p>
#  </a>,
# ...

# %% [markdown]
# ## 5.2 파싱하여 7개 학과 명을 추출하여 print ()하시오

# %%
import re

soup.find_all(string =re.compile("학과"))
# Out:
# ['전공(학과)역량 로드맵',
#  '유기신소재-파이버공학과 정영진 교수',
#  '수학과 황선욱 교수',
#  '전공(학과)역량 로드맵',
#  '\n소프트웨어학과 ',
#  '미디어경영학과',
#  'IT대학은 공학과 자연과학, 사회과학, 예술적인 범주에서 정보기술과',
#  '저희 IT대학 홈페이지를 방문하신 여러분을 환영합니다. 컴퓨터학부, 전자정보공학부[전자공학전공, IT융합전공], 글로벌미디어학부, 소프트웨어학부, AI융합학부, 미디어경영학과로 구성된 IT대학은 하드웨어, 소프트웨어, 콘텐츠를 함께 연구하고 교육하는, IT 분야에 특화된 국내 최초이자 최고의 단과대학입니다. 현재까지 1만 6천 명 이상의 졸업생이 IT분야의 발전을 이끌어가고 있으며, 매년 550여 명 이상의 우수한 신입생이 입학하여 최신 학문을 공부하고 있습니다.',
#  '저희 IT대학 홈페이지를 방문하신 여러분을 환영합니다. 컴퓨터학부, 전자정보공학부[전자공학전공, IT융합전공] 글로벌미디어학부, 소프트웨어학부, 스마트시스템소프트웨어학과, 미디어경영학과로 구성된 IT대학은 하드웨어, 소프트웨어, 콘텐츠를 함께 연구하고 교육하는, IT 분야에 특화된 국내 최초이자 최고의 단과대학입니다.',
#  '6개 학과의 심도 있는 교육과, 빅데이터컴퓨팅, 문화서비스산업, 뉴미디어콘텐츠, 스마트자동차, 정보보호, ICT유통 등 다양한 IT융합 전공을 통한 융합적 지식을 배양합니다.']

# %%
strs = soup.find_all('a', {"class": ["btn btn-info btn-block rounded font-weight-normal icon-right d-flex align-items-center ", "btn btn-success btn-block rounded font-weight-normal icon-right d-flex align-items-center "]})

for i in strs:
    print(i.get_text().strip())
# Out:
# 컴퓨터학부
# 전자정보공학부
# (전자공학전공)
# 전자정보공학부
# (IT융합전공)
# 글로벌미디어학부
# 소프트웨어학부
# 스마트시스템
# 소프트웨어학과
# 미디어경영학과
# (재직자전형)

# %% [markdown]
# ## 6.1 studentlist.csv 데이터에서 키의 outlier 를 찾아 출력 (print)하시오

# %%
plt.boxplot(df.height, vert=False)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x1db74fca9d0>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x1db74c339d0>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x1db74fca670>],
#  'medians': [<matplotlib.lines.Line2D at 0x1db74fb2b50>],
#  'fliers': [<matplotlib.lines.Line2D at 0x1db74fa9580>],
#  'means': []}

# %%
Q1=df.height.quantile(.25)
Q3=df.height.quantile(.75)
border=Q3+(Q3-Q1)*1.5
border
print(df[df['height']>border].height)
# Out:
# 3    196.3
# Name: height, dtype: float64

# %% [markdown]
# ## 6.2 몸무게(종속변수)에 대한 키의 회귀계수를 구하시오

# %%
from scipy import stats
from statsmodels.formula.api import ols, glm 

m1 = ols ( 'weight~height', data=df).fit()  # 모델=ols( '종속변수~독립변수', data=데이터).fit()
m1.summary()
# Out:
# D:\anaconda3\lib\site-packages\scipy\stats\stats.py:1603: UserWarning: kurtosistest only valid for n>=20 ... continuing anyway, n=17
#   warnings.warn("kurtosistest only valid for n>=20 ... continuing "
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                 weight   R-squared:                       0.525
# Model:                            OLS   Adj. R-squared:                  0.493
# Method:                 Least Squares   F-statistic:                     16.58
# Date:                Sat, 01 May 2021   Prob (F-statistic):            0.00100
# Time:                        16:49:00   Log-Likelihood:                -59.311
# No. Observations:                  17   AIC:                             122.6
# Df Residuals:                      15   BIC:                             124.3
# Df Model:                           1
# Covariance Type:            nonrobust
# ...

# %%
print(m1.params[1])
# Out:
# 0.8815509915014159
